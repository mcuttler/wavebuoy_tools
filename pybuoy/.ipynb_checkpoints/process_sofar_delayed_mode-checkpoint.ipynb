# %%
import numpy as np
import pandas as pd
import os
import shutil 
import xarray as xr
import glob 
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %%
#%% set up data paths and output directories

#path for python parser script
parserpath = r'W:\LOWE_IMOS_Deakin_Collab_JUN2020\Data\SofarSpotter\SofarParser\parser_v1.12.0'
parser = 'parser_v1.12.0.py'
#meta data about spotter
buoyID = 'SPOT-0561'

#output path
dpath = r'W:\CUTTLER_DampierArchipelago_DBCA\Data\DEP03(NOV21-JUL22)\OCN_SPOTTER'
# outpath = os.path.join(dpath,buoyID)
outpath = dpath
datapath = os.path.join(dpath,'Raw')
print(datapath)
# Out:
# W:\CUTTLER_DampierArchipelago_DBCA\Data\DEP03(NOV21-JUL22)\OCN_SPOTTER\Raw

# %%
#%% determine number of unique file numbers for chunking data into management number of files
files = os.listdir(datapath)
dum = []
[dum.append(i[0:4]) for i in files]
file_nums = np.unique(np.array(dum))
chunk_size= 10

#Create tmp directory for moving files to process
tmp_path = os.path.join(datapath, 'tmp')
os.mkdir(tmp_path)
shutil.copyfile(os.path.join(parserpath, parser), os.path.join(tmp_path,parser))
# os.chdir(tmp_path)
#could use this on read_csv - fix later 
def sofar_date_parser(x1,x2,x3,x4,x5,x6,x7):
    t = datetime(int(x1),int(x2),int(x3),int(x4),int(x5),int(x6))+timedelta(seconds=float(x7)/1000)
    return t

# %%
#%% loop over chunks and build dataframes 
# import warnings
# warnings.filterwarnings('ignore')

os.chdir(tmp_path)
for i in range(0, len(file_nums), chunk_size):
    print('Processing files ' + str(i) + ' to ' + str(i+chunk_size) + ' out of ' + str(len(file_nums)))
    chunk = file_nums[i:i+chunk_size]
    #move files in chunk to temp folder
    for j in chunk:      
        for k in files:
            if k[0:4]==j:
                shutil.copyfile(os.path.join(datapath, k), os.path.join(tmp_path, k))
    #now process
    try:
        # %run -i parser_v1.12.0.py
#         runfile(os.path.join(tmp_path,parser))
        flag=1
    except: 
        flag=0
 
    if flag==1:
        #check whether parser generated subdirectories or not
        if os.path.exists('bulkparameters.csv')==False:
            ff = os.listdir(tmp_path)
            for checkfile in ff:
                if os.path.isdir(checkfile)==True:
                
                    dumblk = pd.read_csv(os.path.join(tmp_path, checkfile,'bulkparameters.csv'),
                                     parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
    
                    dumdisp = pd.read_csv(os.path.join(tmp_path, checkfile,'displacement.csv'),
                                      parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
                
                    dumloc = pd.read_csv(os.path.join(tmp_path, checkfile, 'location.csv'),
                                     parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser) 
                    duma1 = pd.read_csv(os.path.join(tmp_path,checkfile,'a1.csv'),
                                    parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
                    duma2 = pd.read_csv(os.path.join(tmp_path,checkfile,'a2.csv'),
                                    parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
                    dumb1 = pd.read_csv(os.path.join(tmp_path,checkfile,'b1.csv'),
                                    parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
                    dumb2 = pd.read_csv(os.path.join(tmp_path,checkfile,'b2.csv'),
                                    parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
                    dumSxx = pd.read_csv(os.path.join(tmp_path,checkfile,'Sxx.csv'),
                                     parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
                    dumSyy = pd.read_csv(os.path.join(tmp_path,checkfile,'Syy.csv'),
                                     parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
                    dumSzz = pd.read_csv(os.path.join(tmp_path,checkfile,'Szz.csv'),
                                     parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
                    dumsst = pd.read_csv(os.path.join(tmp_path,checkfile,'sst.csv'),
                                     parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)                                                      
        else:
            dumblk = pd.read_csv('bulkparameters.csv',parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)          
            dumdisp = pd.read_csv('displacement.csv',parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)            
            dumloc = pd.read_csv('location.csv',parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)    
            duma1 = pd.read_csv('a1.csv',parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
            duma2 = pd.read_csv('a2.csv',parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
            dumb1 = pd.read_csv('b1.csv',parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
            dumb2 = pd.read_csv('b2.csv',parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
            dumSxx = pd.read_csv('Sxx.csv',parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
            dumSyy = pd.read_csv('Syy.csv',parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
            dumSzz = pd.read_csv('Szz.csv',parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)
            dumsst = pd.read_csv('sst.csv',parse_dates=[[0,1,2,3,4,5,6]],date_parser=sofar_date_parser)              
    
        if i == 0:
            bulkparams = dumblk
            displacements = dumdisp
            locations = dumloc
            a1 = duma1
            a2 = duma2
            b1 = dumb1
            b2 = dumb2
            Sxx = dumSxx
            Syy = dumSyy
            Szz = dumSzz
            sst = dumsst
        else:
            bulkparams = pd.concat([bulkparams,dumblk],ignore_index=True)
            displacements = pd.concat([displacements,dumdisp],ignore_index=True)
            locations = pd.concat([locations,dumloc],ignore_index=True)
            a1 = pd.concat([a1,duma1],ignore_index=True)
            a2 = pd.concat([a2,duma2],ignore_index=True)
            b1 = pd.concat([b1,dumb1],ignore_index=True)
            b2 = pd.concat([b2,dumb2],ignore_index=True)
            Sxx = pd.concat([Sxx,dumSxx],ignore_index=True)
            Syy = pd.concat([Syy,dumSyy],ignore_index=True)
            Szz = pd.concat([Szz,dumSzz],ignore_index=True)                                
      
        #delete files from tmp directory
        for i in os.listdir(tmp_path):
            if i[-3:]=='csv':
                os.remove(i)
            elif i[-3:]=='CSV':
                os.remove(i)
            elif os.path.isdir(i):
                shutil.rmtree(i)    
    else:
        print('parser did not work')
#delete tmp directory if last file      
print('Finished processing ' + buoyID)
# Out:
# Processing files 0 to 10 out of 260
# Concatenating all FLT files:
# - 0279_FLT.CSV (File 1 out of 9)
# - 0281_FLT.CSV (File 2 out of 9)
# - 0282_FLT.CSV (File 3 out of 9)
# - 0283_FLT.CSV (File 4 out of 9)
# - 0284_FLT.CSV (File 5 out of 9)
# - 0285_FLT.CSV (File 6 out of 9)
# - 0286_FLT.CSV (File 7 out of 9)
# - 0287_FLT.CSV (File 8 out of 9)
# - 0288_FLT.CSV (File 9 out of 9)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0279_SPC.CSV (File 1 out of 8)
# - 0282_SPC.CSV (File 2 out of 8)
# - 0283_SPC.CSV (File 3 out of 8)
# - 0284_SPC.CSV (File 4 out of 8)
# - 0285_SPC.CSV (File 5 out of 8)
# - 0286_SPC.CSV (File 6 out of 8)
# - 0287_SPC.CSV (File 7 out of 8)
# - 0288_SPC.CSV (File 8 out of 8)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0279_SYS.CSV (File 1 out of 10)
# - 0280_SYS.CSV (File 2 out of 10)
# - 0281_SYS.CSV (File 3 out of 10)
# - 0282_SYS.CSV (File 4 out of 10)
# - 0283_SYS.CSV (File 5 out of 10)
# - 0284_SYS.CSV (File 6 out of 10)
# - 0285_SYS.CSV (File 7 out of 10)
# - 0286_SYS.CSV (File 8 out of 10)
# - 0287_SYS.CSV (File 9 out of 10)
# - 0288_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0279_LOC.CSV (File 1 out of 9)
# - 0281_LOC.CSV (File 2 out of 9)
# - 0282_LOC.CSV (File 3 out of 9)
# - 0283_LOC.CSV (File 4 out of 9)
# - 0284_LOC.CSV (File 5 out of 9)
# - 0285_LOC.CSV (File 6 out of 9)
# - 0286_LOC.CSV (File 7 out of 9)
# - 0287_LOC.CSV (File 8 out of 9)
# - 0288_LOC.CSV (File 9 out of 9)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0279_SST.CSV (File 1 out of 10)
# - 0280_SST.CSV (File 2 out of 10)
# - ERROR:, file W:\CUTTLER_DampierArchipelago_DBCA\Data\DEP03(NOV21-JUL22)\OCN_SPOTTER\Raw\tmp\0280_SST.CSV is corrupt
# - 0281_SST.CSV (File 3 out of 10)
# - 0282_SST.CSV (File 4 out of 10)
# - 0283_SST.CSV (File 5 out of 10)
# - 0284_SST.CSV (File 6 out of 10)
# - 0285_SST.CSV (File 7 out of 10)
# - 0286_SST.CSV (File 8 out of 10)
# - 0287_SST.CSV (File 9 out of 10)
# - 0288_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 10 to 20 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0289_FLT.CSV (File 1 out of 10)
# - 0290_FLT.CSV (File 2 out of 10)
# - 0291_FLT.CSV (File 3 out of 10)
# - 0292_FLT.CSV (File 4 out of 10)
# - 0293_FLT.CSV (File 5 out of 10)
# - 0294_FLT.CSV (File 6 out of 10)
# - 0295_FLT.CSV (File 7 out of 10)
# - 0296_FLT.CSV (File 8 out of 10)
# - 0297_FLT.CSV (File 9 out of 10)
# - 0298_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0289_SPC.CSV (File 1 out of 10)
# - 0290_SPC.CSV (File 2 out of 10)
# - 0291_SPC.CSV (File 3 out of 10)
# - 0292_SPC.CSV (File 4 out of 10)
# - 0293_SPC.CSV (File 5 out of 10)
# - 0294_SPC.CSV (File 6 out of 10)
# - 0295_SPC.CSV (File 7 out of 10)
# - 0296_SPC.CSV (File 8 out of 10)
# - 0297_SPC.CSV (File 9 out of 10)
# - 0298_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0289_SYS.CSV (File 1 out of 10)
# - 0290_SYS.CSV (File 2 out of 10)
# - 0291_SYS.CSV (File 3 out of 10)
# - 0292_SYS.CSV (File 4 out of 10)
# - 0293_SYS.CSV (File 5 out of 10)
# - 0294_SYS.CSV (File 6 out of 10)
# - 0295_SYS.CSV (File 7 out of 10)
# - 0296_SYS.CSV (File 8 out of 10)
# - 0297_SYS.CSV (File 9 out of 10)
# - 0298_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0289_LOC.CSV (File 1 out of 10)
# - 0290_LOC.CSV (File 2 out of 10)
# - 0291_LOC.CSV (File 3 out of 10)
# - 0292_LOC.CSV (File 4 out of 10)
# - 0293_LOC.CSV (File 5 out of 10)
# - 0294_LOC.CSV (File 6 out of 10)
# - 0295_LOC.CSV (File 7 out of 10)
# - 0296_LOC.CSV (File 8 out of 10)
# - 0297_LOC.CSV (File 9 out of 10)
# - 0298_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0289_SST.CSV (File 1 out of 10)
# - 0290_SST.CSV (File 2 out of 10)
# - 0291_SST.CSV (File 3 out of 10)
# - 0292_SST.CSV (File 4 out of 10)
# - 0293_SST.CSV (File 5 out of 10)
# - 0294_SST.CSV (File 6 out of 10)
# - 0295_SST.CSV (File 7 out of 10)
# - 0296_SST.CSV (File 8 out of 10)
# - 0297_SST.CSV (File 9 out of 10)
# - 0298_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 20 to 30 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0299_FLT.CSV (File 1 out of 10)
# - 0300_FLT.CSV (File 2 out of 10)
# - 0301_FLT.CSV (File 3 out of 10)
# - 0302_FLT.CSV (File 4 out of 10)
# - 0303_FLT.CSV (File 5 out of 10)
# - 0304_FLT.CSV (File 6 out of 10)
# - 0305_FLT.CSV (File 7 out of 10)
# - 0306_FLT.CSV (File 8 out of 10)
# - 0307_FLT.CSV (File 9 out of 10)
# - 0308_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0299_SPC.CSV (File 1 out of 10)
# - 0300_SPC.CSV (File 2 out of 10)
# - 0301_SPC.CSV (File 3 out of 10)
# - 0302_SPC.CSV (File 4 out of 10)
# - 0303_SPC.CSV (File 5 out of 10)
# - 0304_SPC.CSV (File 6 out of 10)
# - 0305_SPC.CSV (File 7 out of 10)
# - 0306_SPC.CSV (File 8 out of 10)
# - 0307_SPC.CSV (File 9 out of 10)
# - 0308_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0299_SYS.CSV (File 1 out of 10)
# - 0300_SYS.CSV (File 2 out of 10)
# - 0301_SYS.CSV (File 3 out of 10)
# - 0302_SYS.CSV (File 4 out of 10)
# - 0303_SYS.CSV (File 5 out of 10)
# - 0304_SYS.CSV (File 6 out of 10)
# - 0305_SYS.CSV (File 7 out of 10)
# - 0306_SYS.CSV (File 8 out of 10)
# - 0307_SYS.CSV (File 9 out of 10)
# - 0308_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0299_LOC.CSV (File 1 out of 10)
# - 0300_LOC.CSV (File 2 out of 10)
# - 0301_LOC.CSV (File 3 out of 10)
# - 0302_LOC.CSV (File 4 out of 10)
# - 0303_LOC.CSV (File 5 out of 10)
# - 0304_LOC.CSV (File 6 out of 10)
# - 0305_LOC.CSV (File 7 out of 10)
# - 0306_LOC.CSV (File 8 out of 10)
# - 0307_LOC.CSV (File 9 out of 10)
# - 0308_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0299_SST.CSV (File 1 out of 10)
# - 0300_SST.CSV (File 2 out of 10)
# - 0301_SST.CSV (File 3 out of 10)
# - 0302_SST.CSV (File 4 out of 10)
# - 0303_SST.CSV (File 5 out of 10)
# - 0304_SST.CSV (File 6 out of 10)
# - 0305_SST.CSV (File 7 out of 10)
# - 0306_SST.CSV (File 8 out of 10)
# - 0307_SST.CSV (File 9 out of 10)
# - 0308_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 30 to 40 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0309_FLT.CSV (File 1 out of 10)
# - 0310_FLT.CSV (File 2 out of 10)
# - 0311_FLT.CSV (File 3 out of 10)
# - 0312_FLT.CSV (File 4 out of 10)
# - 0313_FLT.CSV (File 5 out of 10)
# - 0314_FLT.CSV (File 6 out of 10)
# - 0315_FLT.CSV (File 7 out of 10)
# - 0316_FLT.CSV (File 8 out of 10)
# - 0317_FLT.CSV (File 9 out of 10)
# - 0318_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0309_SPC.CSV (File 1 out of 10)
# - 0310_SPC.CSV (File 2 out of 10)
# - 0311_SPC.CSV (File 3 out of 10)
# - 0312_SPC.CSV (File 4 out of 10)
# - 0313_SPC.CSV (File 5 out of 10)
# - 0314_SPC.CSV (File 6 out of 10)
# - 0315_SPC.CSV (File 7 out of 10)
# - 0316_SPC.CSV (File 8 out of 10)
# - 0317_SPC.CSV (File 9 out of 10)
# - 0318_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0309_SYS.CSV (File 1 out of 10)
# - 0310_SYS.CSV (File 2 out of 10)
# - 0311_SYS.CSV (File 3 out of 10)
# - 0312_SYS.CSV (File 4 out of 10)
# - 0313_SYS.CSV (File 5 out of 10)
# - 0314_SYS.CSV (File 6 out of 10)
# - 0315_SYS.CSV (File 7 out of 10)
# - 0316_SYS.CSV (File 8 out of 10)
# - 0317_SYS.CSV (File 9 out of 10)
# - 0318_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0309_LOC.CSV (File 1 out of 10)
# - 0310_LOC.CSV (File 2 out of 10)
# - 0311_LOC.CSV (File 3 out of 10)
# - 0312_LOC.CSV (File 4 out of 10)
# - 0313_LOC.CSV (File 5 out of 10)
# - 0314_LOC.CSV (File 6 out of 10)
# - 0315_LOC.CSV (File 7 out of 10)
# - 0316_LOC.CSV (File 8 out of 10)
# - 0317_LOC.CSV (File 9 out of 10)
# - 0318_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0309_SST.CSV (File 1 out of 10)
# - 0310_SST.CSV (File 2 out of 10)
# - 0311_SST.CSV (File 3 out of 10)
# - 0312_SST.CSV (File 4 out of 10)
# - 0313_SST.CSV (File 5 out of 10)
# - 0314_SST.CSV (File 6 out of 10)
# - 0315_SST.CSV (File 7 out of 10)
# - 0316_SST.CSV (File 8 out of 10)
# - 0317_SST.CSV (File 9 out of 10)
# - 0318_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 40 to 50 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0319_FLT.CSV (File 1 out of 10)
# - 0320_FLT.CSV (File 2 out of 10)
# - 0321_FLT.CSV (File 3 out of 10)
# - 0322_FLT.CSV (File 4 out of 10)
# - 0323_FLT.CSV (File 5 out of 10)
# - 0324_FLT.CSV (File 6 out of 10)
# - 0325_FLT.CSV (File 7 out of 10)
# - 0326_FLT.CSV (File 8 out of 10)
# - 0327_FLT.CSV (File 9 out of 10)
# - 0328_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0319_SPC.CSV (File 1 out of 10)
# - 0320_SPC.CSV (File 2 out of 10)
# - 0321_SPC.CSV (File 3 out of 10)
# - 0322_SPC.CSV (File 4 out of 10)
# - 0323_SPC.CSV (File 5 out of 10)
# - 0324_SPC.CSV (File 6 out of 10)
# - 0325_SPC.CSV (File 7 out of 10)
# - 0326_SPC.CSV (File 8 out of 10)
# - 0327_SPC.CSV (File 9 out of 10)
# - 0328_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0319_SYS.CSV (File 1 out of 10)
# - 0320_SYS.CSV (File 2 out of 10)
# - 0321_SYS.CSV (File 3 out of 10)
# - 0322_SYS.CSV (File 4 out of 10)
# - 0323_SYS.CSV (File 5 out of 10)
# - 0324_SYS.CSV (File 6 out of 10)
# - 0325_SYS.CSV (File 7 out of 10)
# - 0326_SYS.CSV (File 8 out of 10)
# - 0327_SYS.CSV (File 9 out of 10)
# - 0328_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0319_LOC.CSV (File 1 out of 10)
# - 0320_LOC.CSV (File 2 out of 10)
# - 0321_LOC.CSV (File 3 out of 10)
# - 0322_LOC.CSV (File 4 out of 10)
# - 0323_LOC.CSV (File 5 out of 10)
# - 0324_LOC.CSV (File 6 out of 10)
# - 0325_LOC.CSV (File 7 out of 10)
# - 0326_LOC.CSV (File 8 out of 10)
# - 0327_LOC.CSV (File 9 out of 10)
# - 0328_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0319_SST.CSV (File 1 out of 10)
# - 0320_SST.CSV (File 2 out of 10)
# - 0321_SST.CSV (File 3 out of 10)
# - 0322_SST.CSV (File 4 out of 10)
# - 0323_SST.CSV (File 5 out of 10)
# - 0324_SST.CSV (File 6 out of 10)
# - 0325_SST.CSV (File 7 out of 10)
# - 0326_SST.CSV (File 8 out of 10)
# - 0327_SST.CSV (File 9 out of 10)
# - 0328_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 50 to 60 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0329_FLT.CSV (File 1 out of 10)
# - 0330_FLT.CSV (File 2 out of 10)
# - 0331_FLT.CSV (File 3 out of 10)
# - 0332_FLT.CSV (File 4 out of 10)
# - 0333_FLT.CSV (File 5 out of 10)
# - 0334_FLT.CSV (File 6 out of 10)
# - 0335_FLT.CSV (File 7 out of 10)
# - 0336_FLT.CSV (File 8 out of 10)
# - 0337_FLT.CSV (File 9 out of 10)
# - 0338_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0329_SPC.CSV (File 1 out of 10)
# - 0330_SPC.CSV (File 2 out of 10)
# - 0331_SPC.CSV (File 3 out of 10)
# - 0332_SPC.CSV (File 4 out of 10)
# - 0333_SPC.CSV (File 5 out of 10)
# - 0334_SPC.CSV (File 6 out of 10)
# - 0335_SPC.CSV (File 7 out of 10)
# - 0336_SPC.CSV (File 8 out of 10)
# - 0337_SPC.CSV (File 9 out of 10)
# - 0338_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0329_SYS.CSV (File 1 out of 10)
# - 0330_SYS.CSV (File 2 out of 10)
# - 0331_SYS.CSV (File 3 out of 10)
# - 0332_SYS.CSV (File 4 out of 10)
# - 0333_SYS.CSV (File 5 out of 10)
# - 0334_SYS.CSV (File 6 out of 10)
# - 0335_SYS.CSV (File 7 out of 10)
# - 0336_SYS.CSV (File 8 out of 10)
# - 0337_SYS.CSV (File 9 out of 10)
# - 0338_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0329_LOC.CSV (File 1 out of 10)
# - 0330_LOC.CSV (File 2 out of 10)
# - 0331_LOC.CSV (File 3 out of 10)
# - 0332_LOC.CSV (File 4 out of 10)
# - 0333_LOC.CSV (File 5 out of 10)
# - 0334_LOC.CSV (File 6 out of 10)
# - 0335_LOC.CSV (File 7 out of 10)
# - 0336_LOC.CSV (File 8 out of 10)
# - 0337_LOC.CSV (File 9 out of 10)
# - 0338_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0329_SST.CSV (File 1 out of 10)
# - 0330_SST.CSV (File 2 out of 10)
# - 0331_SST.CSV (File 3 out of 10)
# - 0332_SST.CSV (File 4 out of 10)
# - 0333_SST.CSV (File 5 out of 10)
# - 0334_SST.CSV (File 6 out of 10)
# - 0335_SST.CSV (File 7 out of 10)
# - 0336_SST.CSV (File 8 out of 10)
# - 0337_SST.CSV (File 9 out of 10)
# - 0338_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 60 to 70 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0339_FLT.CSV (File 1 out of 10)
# - 0340_FLT.CSV (File 2 out of 10)
# - 0341_FLT.CSV (File 3 out of 10)
# - 0342_FLT.CSV (File 4 out of 10)
# - 0343_FLT.CSV (File 5 out of 10)
# - 0344_FLT.CSV (File 6 out of 10)
# - 0345_FLT.CSV (File 7 out of 10)
# - 0346_FLT.CSV (File 8 out of 10)
# - 0347_FLT.CSV (File 9 out of 10)
# - 0348_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0339_SPC.CSV (File 1 out of 10)
# - 0340_SPC.CSV (File 2 out of 10)
# - 0341_SPC.CSV (File 3 out of 10)
# - 0342_SPC.CSV (File 4 out of 10)
# - 0343_SPC.CSV (File 5 out of 10)
# - 0344_SPC.CSV (File 6 out of 10)
# - 0345_SPC.CSV (File 7 out of 10)
# - 0346_SPC.CSV (File 8 out of 10)
# - 0347_SPC.CSV (File 9 out of 10)
# - 0348_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0339_SYS.CSV (File 1 out of 10)
# - 0340_SYS.CSV (File 2 out of 10)
# - 0341_SYS.CSV (File 3 out of 10)
# - 0342_SYS.CSV (File 4 out of 10)
# - 0343_SYS.CSV (File 5 out of 10)
# - 0344_SYS.CSV (File 6 out of 10)
# - 0345_SYS.CSV (File 7 out of 10)
# - 0346_SYS.CSV (File 8 out of 10)
# - 0347_SYS.CSV (File 9 out of 10)
# - 0348_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0339_LOC.CSV (File 1 out of 10)
# - 0340_LOC.CSV (File 2 out of 10)
# - 0341_LOC.CSV (File 3 out of 10)
# - 0342_LOC.CSV (File 4 out of 10)
# - 0343_LOC.CSV (File 5 out of 10)
# - 0344_LOC.CSV (File 6 out of 10)
# - 0345_LOC.CSV (File 7 out of 10)
# - 0346_LOC.CSV (File 8 out of 10)
# - 0347_LOC.CSV (File 9 out of 10)
# - 0348_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0339_SST.CSV (File 1 out of 10)
# - 0340_SST.CSV (File 2 out of 10)
# - 0341_SST.CSV (File 3 out of 10)
# - 0342_SST.CSV (File 4 out of 10)
# - 0343_SST.CSV (File 5 out of 10)
# - 0344_SST.CSV (File 6 out of 10)
# - 0345_SST.CSV (File 7 out of 10)
# - 0346_SST.CSV (File 8 out of 10)
# - 0347_SST.CSV (File 9 out of 10)
# - 0348_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 70 to 80 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0349_FLT.CSV (File 1 out of 10)
# - 0350_FLT.CSV (File 2 out of 10)
# - 0351_FLT.CSV (File 3 out of 10)
# - 0352_FLT.CSV (File 4 out of 10)
# - 0353_FLT.CSV (File 5 out of 10)
# - 0354_FLT.CSV (File 6 out of 10)
# - 0355_FLT.CSV (File 7 out of 10)
# - 0356_FLT.CSV (File 8 out of 10)
# - 0357_FLT.CSV (File 9 out of 10)
# - 0358_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0349_SPC.CSV (File 1 out of 10)
# - 0350_SPC.CSV (File 2 out of 10)
# - 0351_SPC.CSV (File 3 out of 10)
# - 0352_SPC.CSV (File 4 out of 10)
# - 0353_SPC.CSV (File 5 out of 10)
# - 0354_SPC.CSV (File 6 out of 10)
# - 0355_SPC.CSV (File 7 out of 10)
# - 0356_SPC.CSV (File 8 out of 10)
# - 0357_SPC.CSV (File 9 out of 10)
# - 0358_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0349_SYS.CSV (File 1 out of 10)
# - 0350_SYS.CSV (File 2 out of 10)
# - 0351_SYS.CSV (File 3 out of 10)
# - 0352_SYS.CSV (File 4 out of 10)
# - 0353_SYS.CSV (File 5 out of 10)
# - 0354_SYS.CSV (File 6 out of 10)
# - 0355_SYS.CSV (File 7 out of 10)
# - 0356_SYS.CSV (File 8 out of 10)
# - 0357_SYS.CSV (File 9 out of 10)
# - 0358_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0349_LOC.CSV (File 1 out of 10)
# - 0350_LOC.CSV (File 2 out of 10)
# - 0351_LOC.CSV (File 3 out of 10)
# - 0352_LOC.CSV (File 4 out of 10)
# - 0353_LOC.CSV (File 5 out of 10)
# - 0354_LOC.CSV (File 6 out of 10)
# - 0355_LOC.CSV (File 7 out of 10)
# - 0356_LOC.CSV (File 8 out of 10)
# - 0357_LOC.CSV (File 9 out of 10)
# - 0358_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0349_SST.CSV (File 1 out of 10)
# - 0350_SST.CSV (File 2 out of 10)
# - 0351_SST.CSV (File 3 out of 10)
# - 0352_SST.CSV (File 4 out of 10)
# - 0353_SST.CSV (File 5 out of 10)
# - 0354_SST.CSV (File 6 out of 10)
# - 0355_SST.CSV (File 7 out of 10)
# - 0356_SST.CSV (File 8 out of 10)
# - 0357_SST.CSV (File 9 out of 10)
# - 0358_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 80 to 90 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0359_FLT.CSV (File 1 out of 10)
# - 0360_FLT.CSV (File 2 out of 10)
# - 0361_FLT.CSV (File 3 out of 10)
# - 0362_FLT.CSV (File 4 out of 10)
# - 0363_FLT.CSV (File 5 out of 10)
# - 0364_FLT.CSV (File 6 out of 10)
# - 0365_FLT.CSV (File 7 out of 10)
# - 0366_FLT.CSV (File 8 out of 10)
# - 0367_FLT.CSV (File 9 out of 10)
# - 0368_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0359_SPC.CSV (File 1 out of 10)
# - 0360_SPC.CSV (File 2 out of 10)
# - 0361_SPC.CSV (File 3 out of 10)
# - 0362_SPC.CSV (File 4 out of 10)
# - 0363_SPC.CSV (File 5 out of 10)
# - 0364_SPC.CSV (File 6 out of 10)
# - 0365_SPC.CSV (File 7 out of 10)
# - 0366_SPC.CSV (File 8 out of 10)
# - 0367_SPC.CSV (File 9 out of 10)
# - 0368_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0359_SYS.CSV (File 1 out of 10)
# - 0360_SYS.CSV (File 2 out of 10)
# - 0361_SYS.CSV (File 3 out of 10)
# - 0362_SYS.CSV (File 4 out of 10)
# - 0363_SYS.CSV (File 5 out of 10)
# - 0364_SYS.CSV (File 6 out of 10)
# - 0365_SYS.CSV (File 7 out of 10)
# - 0366_SYS.CSV (File 8 out of 10)
# - 0367_SYS.CSV (File 9 out of 10)
# - 0368_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0359_LOC.CSV (File 1 out of 10)
# - 0360_LOC.CSV (File 2 out of 10)
# - 0361_LOC.CSV (File 3 out of 10)
# - 0362_LOC.CSV (File 4 out of 10)
# - 0363_LOC.CSV (File 5 out of 10)
# - 0364_LOC.CSV (File 6 out of 10)
# - 0365_LOC.CSV (File 7 out of 10)
# - 0366_LOC.CSV (File 8 out of 10)
# - 0367_LOC.CSV (File 9 out of 10)
# - 0368_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0359_SST.CSV (File 1 out of 10)
# - 0360_SST.CSV (File 2 out of 10)
# - 0361_SST.CSV (File 3 out of 10)
# - 0362_SST.CSV (File 4 out of 10)
# - 0363_SST.CSV (File 5 out of 10)
# - 0364_SST.CSV (File 6 out of 10)
# - 0365_SST.CSV (File 7 out of 10)
# - 0366_SST.CSV (File 8 out of 10)
# - 0367_SST.CSV (File 9 out of 10)
# - 0368_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 90 to 100 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0369_FLT.CSV (File 1 out of 10)
# - 0370_FLT.CSV (File 2 out of 10)
# - 0371_FLT.CSV (File 3 out of 10)
# - 0372_FLT.CSV (File 4 out of 10)
# - 0373_FLT.CSV (File 5 out of 10)
# - 0374_FLT.CSV (File 6 out of 10)
# - 0375_FLT.CSV (File 7 out of 10)
# - 0376_FLT.CSV (File 8 out of 10)
# - 0377_FLT.CSV (File 9 out of 10)
# - 0378_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0369_SPC.CSV (File 1 out of 10)
# - 0370_SPC.CSV (File 2 out of 10)
# - 0371_SPC.CSV (File 3 out of 10)
# - 0372_SPC.CSV (File 4 out of 10)
# - 0373_SPC.CSV (File 5 out of 10)
# - 0374_SPC.CSV (File 6 out of 10)
# - 0375_SPC.CSV (File 7 out of 10)
# - 0376_SPC.CSV (File 8 out of 10)
# - 0377_SPC.CSV (File 9 out of 10)
# - 0378_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0369_SYS.CSV (File 1 out of 10)
# - 0370_SYS.CSV (File 2 out of 10)
# - 0371_SYS.CSV (File 3 out of 10)
# - 0372_SYS.CSV (File 4 out of 10)
# - 0373_SYS.CSV (File 5 out of 10)
# - 0374_SYS.CSV (File 6 out of 10)
# - 0375_SYS.CSV (File 7 out of 10)
# - 0376_SYS.CSV (File 8 out of 10)
# - 0377_SYS.CSV (File 9 out of 10)
# - 0378_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0369_LOC.CSV (File 1 out of 10)
# - 0370_LOC.CSV (File 2 out of 10)
# - 0371_LOC.CSV (File 3 out of 10)
# - 0372_LOC.CSV (File 4 out of 10)
# - 0373_LOC.CSV (File 5 out of 10)
# - 0374_LOC.CSV (File 6 out of 10)
# - 0375_LOC.CSV (File 7 out of 10)
# - 0376_LOC.CSV (File 8 out of 10)
# - 0377_LOC.CSV (File 9 out of 10)
# - 0378_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0369_SST.CSV (File 1 out of 10)
# - 0370_SST.CSV (File 2 out of 10)
# - 0371_SST.CSV (File 3 out of 10)
# - 0372_SST.CSV (File 4 out of 10)
# - 0373_SST.CSV (File 5 out of 10)
# - 0374_SST.CSV (File 6 out of 10)
# - 0375_SST.CSV (File 7 out of 10)
# - 0376_SST.CSV (File 8 out of 10)
# - 0377_SST.CSV (File 9 out of 10)
# - 0378_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 100 to 110 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0379_FLT.CSV (File 1 out of 10)
# - 0380_FLT.CSV (File 2 out of 10)
# - 0381_FLT.CSV (File 3 out of 10)
# - 0382_FLT.CSV (File 4 out of 10)
# - 0383_FLT.CSV (File 5 out of 10)
# - 0384_FLT.CSV (File 6 out of 10)
# - 0385_FLT.CSV (File 7 out of 10)
# - 0386_FLT.CSV (File 8 out of 10)
# - 0387_FLT.CSV (File 9 out of 10)
# - 0388_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0379_SPC.CSV (File 1 out of 10)
# - 0380_SPC.CSV (File 2 out of 10)
# - 0381_SPC.CSV (File 3 out of 10)
# - 0382_SPC.CSV (File 4 out of 10)
# - 0383_SPC.CSV (File 5 out of 10)
# - 0384_SPC.CSV (File 6 out of 10)
# - 0385_SPC.CSV (File 7 out of 10)
# - 0386_SPC.CSV (File 8 out of 10)
# - 0387_SPC.CSV (File 9 out of 10)
# - 0388_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0379_SYS.CSV (File 1 out of 10)
# - 0380_SYS.CSV (File 2 out of 10)
# - 0381_SYS.CSV (File 3 out of 10)
# - 0382_SYS.CSV (File 4 out of 10)
# - 0383_SYS.CSV (File 5 out of 10)
# - 0384_SYS.CSV (File 6 out of 10)
# - 0385_SYS.CSV (File 7 out of 10)
# - 0386_SYS.CSV (File 8 out of 10)
# - 0387_SYS.CSV (File 9 out of 10)
# - 0388_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0379_LOC.CSV (File 1 out of 10)
# - 0380_LOC.CSV (File 2 out of 10)
# - 0381_LOC.CSV (File 3 out of 10)
# - 0382_LOC.CSV (File 4 out of 10)
# - 0383_LOC.CSV (File 5 out of 10)
# - 0384_LOC.CSV (File 6 out of 10)
# - 0385_LOC.CSV (File 7 out of 10)
# - 0386_LOC.CSV (File 8 out of 10)
# - 0387_LOC.CSV (File 9 out of 10)
# - 0388_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0379_SST.CSV (File 1 out of 10)
# - 0380_SST.CSV (File 2 out of 10)
# - 0381_SST.CSV (File 3 out of 10)
# - 0382_SST.CSV (File 4 out of 10)
# - 0383_SST.CSV (File 5 out of 10)
# - 0384_SST.CSV (File 6 out of 10)
# - 0385_SST.CSV (File 7 out of 10)
# - 0386_SST.CSV (File 8 out of 10)
# - 0387_SST.CSV (File 9 out of 10)
# - 0388_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 110 to 120 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0389_FLT.CSV (File 1 out of 10)
# - 0390_FLT.CSV (File 2 out of 10)
# - 0391_FLT.CSV (File 3 out of 10)
# - 0392_FLT.CSV (File 4 out of 10)
# - 0393_FLT.CSV (File 5 out of 10)
# - 0394_FLT.CSV (File 6 out of 10)
# - 0395_FLT.CSV (File 7 out of 10)
# - 0396_FLT.CSV (File 8 out of 10)
# - 0397_FLT.CSV (File 9 out of 10)
# - 0398_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0389_SPC.CSV (File 1 out of 10)
# - 0390_SPC.CSV (File 2 out of 10)
# - 0391_SPC.CSV (File 3 out of 10)
# - 0392_SPC.CSV (File 4 out of 10)
# - 0393_SPC.CSV (File 5 out of 10)
# - 0394_SPC.CSV (File 6 out of 10)
# - 0395_SPC.CSV (File 7 out of 10)
# - 0396_SPC.CSV (File 8 out of 10)
# - 0397_SPC.CSV (File 9 out of 10)
# - 0398_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0389_SYS.CSV (File 1 out of 10)
# - 0390_SYS.CSV (File 2 out of 10)
# - 0391_SYS.CSV (File 3 out of 10)
# - 0392_SYS.CSV (File 4 out of 10)
# - 0393_SYS.CSV (File 5 out of 10)
# - 0394_SYS.CSV (File 6 out of 10)
# - 0395_SYS.CSV (File 7 out of 10)
# - 0396_SYS.CSV (File 8 out of 10)
# - 0397_SYS.CSV (File 9 out of 10)
# - 0398_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0389_LOC.CSV (File 1 out of 10)
# - 0390_LOC.CSV (File 2 out of 10)
# - 0391_LOC.CSV (File 3 out of 10)
# - 0392_LOC.CSV (File 4 out of 10)
# - 0393_LOC.CSV (File 5 out of 10)
# - 0394_LOC.CSV (File 6 out of 10)
# - 0395_LOC.CSV (File 7 out of 10)
# - 0396_LOC.CSV (File 8 out of 10)
# - 0397_LOC.CSV (File 9 out of 10)
# - 0398_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0389_SST.CSV (File 1 out of 10)
# - 0390_SST.CSV (File 2 out of 10)
# - 0391_SST.CSV (File 3 out of 10)
# - 0392_SST.CSV (File 4 out of 10)
# - 0393_SST.CSV (File 5 out of 10)
# - 0394_SST.CSV (File 6 out of 10)
# - 0395_SST.CSV (File 7 out of 10)
# - 0396_SST.CSV (File 8 out of 10)
# - 0397_SST.CSV (File 9 out of 10)
# - 0398_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 120 to 130 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0399_FLT.CSV (File 1 out of 10)
# - 0400_FLT.CSV (File 2 out of 10)
# - 0401_FLT.CSV (File 3 out of 10)
# - 0402_FLT.CSV (File 4 out of 10)
# - 0403_FLT.CSV (File 5 out of 10)
# - 0404_FLT.CSV (File 6 out of 10)
# - 0405_FLT.CSV (File 7 out of 10)
# - 0406_FLT.CSV (File 8 out of 10)
# - 0407_FLT.CSV (File 9 out of 10)
# - 0408_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0399_SPC.CSV (File 1 out of 10)
# - 0400_SPC.CSV (File 2 out of 10)
# - 0401_SPC.CSV (File 3 out of 10)
# - 0402_SPC.CSV (File 4 out of 10)
# - 0403_SPC.CSV (File 5 out of 10)
# - 0404_SPC.CSV (File 6 out of 10)
# - 0405_SPC.CSV (File 7 out of 10)
# - 0406_SPC.CSV (File 8 out of 10)
# - 0407_SPC.CSV (File 9 out of 10)
# - 0408_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0399_SYS.CSV (File 1 out of 10)
# - 0400_SYS.CSV (File 2 out of 10)
# - 0401_SYS.CSV (File 3 out of 10)
# - 0402_SYS.CSV (File 4 out of 10)
# - 0403_SYS.CSV (File 5 out of 10)
# - 0404_SYS.CSV (File 6 out of 10)
# - 0405_SYS.CSV (File 7 out of 10)
# - 0406_SYS.CSV (File 8 out of 10)
# - 0407_SYS.CSV (File 9 out of 10)
# - 0408_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0399_LOC.CSV (File 1 out of 10)
# - 0400_LOC.CSV (File 2 out of 10)
# - 0401_LOC.CSV (File 3 out of 10)
# - 0402_LOC.CSV (File 4 out of 10)
# - 0403_LOC.CSV (File 5 out of 10)
# - 0404_LOC.CSV (File 6 out of 10)
# - 0405_LOC.CSV (File 7 out of 10)
# - 0406_LOC.CSV (File 8 out of 10)
# - 0407_LOC.CSV (File 9 out of 10)
# - 0408_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0399_SST.CSV (File 1 out of 10)
# - 0400_SST.CSV (File 2 out of 10)
# - 0401_SST.CSV (File 3 out of 10)
# - 0402_SST.CSV (File 4 out of 10)
# - 0403_SST.CSV (File 5 out of 10)
# - 0404_SST.CSV (File 6 out of 10)
# - 0405_SST.CSV (File 7 out of 10)
# - 0406_SST.CSV (File 8 out of 10)
# - 0407_SST.CSV (File 9 out of 10)
# - 0408_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 130 to 140 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0409_FLT.CSV (File 1 out of 10)
# - 0410_FLT.CSV (File 2 out of 10)
# - 0411_FLT.CSV (File 3 out of 10)
# - 0412_FLT.CSV (File 4 out of 10)
# - 0413_FLT.CSV (File 5 out of 10)
# - 0414_FLT.CSV (File 6 out of 10)
# - 0415_FLT.CSV (File 7 out of 10)
# - 0416_FLT.CSV (File 8 out of 10)
# - 0417_FLT.CSV (File 9 out of 10)
# - 0418_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0409_SPC.CSV (File 1 out of 10)
# - 0410_SPC.CSV (File 2 out of 10)
# - 0411_SPC.CSV (File 3 out of 10)
# - 0412_SPC.CSV (File 4 out of 10)
# - 0413_SPC.CSV (File 5 out of 10)
# - 0414_SPC.CSV (File 6 out of 10)
# - 0415_SPC.CSV (File 7 out of 10)
# - 0416_SPC.CSV (File 8 out of 10)
# - 0417_SPC.CSV (File 9 out of 10)
# - 0418_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0409_SYS.CSV (File 1 out of 10)
# - 0410_SYS.CSV (File 2 out of 10)
# - 0411_SYS.CSV (File 3 out of 10)
# - 0412_SYS.CSV (File 4 out of 10)
# - 0413_SYS.CSV (File 5 out of 10)
# - 0414_SYS.CSV (File 6 out of 10)
# - 0415_SYS.CSV (File 7 out of 10)
# - 0416_SYS.CSV (File 8 out of 10)
# - 0417_SYS.CSV (File 9 out of 10)
# - 0418_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0409_LOC.CSV (File 1 out of 10)
# - 0410_LOC.CSV (File 2 out of 10)
# - 0411_LOC.CSV (File 3 out of 10)
# - 0412_LOC.CSV (File 4 out of 10)
# - 0413_LOC.CSV (File 5 out of 10)
# - 0414_LOC.CSV (File 6 out of 10)
# - 0415_LOC.CSV (File 7 out of 10)
# - 0416_LOC.CSV (File 8 out of 10)
# - 0417_LOC.CSV (File 9 out of 10)
# - 0418_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0409_SST.CSV (File 1 out of 10)
# - 0410_SST.CSV (File 2 out of 10)
# - 0411_SST.CSV (File 3 out of 10)
# - 0412_SST.CSV (File 4 out of 10)
# - 0413_SST.CSV (File 5 out of 10)
# - 0414_SST.CSV (File 6 out of 10)
# - 0415_SST.CSV (File 7 out of 10)
# - 0416_SST.CSV (File 8 out of 10)
# - 0417_SST.CSV (File 9 out of 10)
# - 0418_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 140 to 150 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0419_FLT.CSV (File 1 out of 10)
# - 0420_FLT.CSV (File 2 out of 10)
# - 0421_FLT.CSV (File 3 out of 10)
# - 0422_FLT.CSV (File 4 out of 10)
# - 0423_FLT.CSV (File 5 out of 10)
# - 0424_FLT.CSV (File 6 out of 10)
# - 0425_FLT.CSV (File 7 out of 10)
# - 0426_FLT.CSV (File 8 out of 10)
# - 0427_FLT.CSV (File 9 out of 10)
# - 0428_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0419_SPC.CSV (File 1 out of 10)
# - 0420_SPC.CSV (File 2 out of 10)
# - 0421_SPC.CSV (File 3 out of 10)
# - 0422_SPC.CSV (File 4 out of 10)
# - 0423_SPC.CSV (File 5 out of 10)
# - 0424_SPC.CSV (File 6 out of 10)
# - 0425_SPC.CSV (File 7 out of 10)
# - 0426_SPC.CSV (File 8 out of 10)
# - 0427_SPC.CSV (File 9 out of 10)
# - 0428_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0419_SYS.CSV (File 1 out of 10)
# - 0420_SYS.CSV (File 2 out of 10)
# - 0421_SYS.CSV (File 3 out of 10)
# - 0422_SYS.CSV (File 4 out of 10)
# - 0423_SYS.CSV (File 5 out of 10)
# - 0424_SYS.CSV (File 6 out of 10)
# - 0425_SYS.CSV (File 7 out of 10)
# - 0426_SYS.CSV (File 8 out of 10)
# - 0427_SYS.CSV (File 9 out of 10)
# - 0428_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0419_LOC.CSV (File 1 out of 10)
# - 0420_LOC.CSV (File 2 out of 10)
# - 0421_LOC.CSV (File 3 out of 10)
# - 0422_LOC.CSV (File 4 out of 10)
# - 0423_LOC.CSV (File 5 out of 10)
# - 0424_LOC.CSV (File 6 out of 10)
# - 0425_LOC.CSV (File 7 out of 10)
# - 0426_LOC.CSV (File 8 out of 10)
# - 0427_LOC.CSV (File 9 out of 10)
# - 0428_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0419_SST.CSV (File 1 out of 10)
# - 0420_SST.CSV (File 2 out of 10)
# - 0421_SST.CSV (File 3 out of 10)
# - 0422_SST.CSV (File 4 out of 10)
# - 0423_SST.CSV (File 5 out of 10)
# - 0424_SST.CSV (File 6 out of 10)
# - 0425_SST.CSV (File 7 out of 10)
# - 0426_SST.CSV (File 8 out of 10)
# - 0427_SST.CSV (File 9 out of 10)
# - 0428_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 150 to 160 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0429_FLT.CSV (File 1 out of 10)
# - 0430_FLT.CSV (File 2 out of 10)
# - 0431_FLT.CSV (File 3 out of 10)
# - 0432_FLT.CSV (File 4 out of 10)
# - 0433_FLT.CSV (File 5 out of 10)
# - 0434_FLT.CSV (File 6 out of 10)
# - 0435_FLT.CSV (File 7 out of 10)
# - 0436_FLT.CSV (File 8 out of 10)
# - 0437_FLT.CSV (File 9 out of 10)
# - 0438_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0429_SPC.CSV (File 1 out of 10)
# - 0430_SPC.CSV (File 2 out of 10)
# - 0431_SPC.CSV (File 3 out of 10)
# - 0432_SPC.CSV (File 4 out of 10)
# - 0433_SPC.CSV (File 5 out of 10)
# - 0434_SPC.CSV (File 6 out of 10)
# - 0435_SPC.CSV (File 7 out of 10)
# - 0436_SPC.CSV (File 8 out of 10)
# - 0437_SPC.CSV (File 9 out of 10)
# - 0438_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0429_SYS.CSV (File 1 out of 10)
# - 0430_SYS.CSV (File 2 out of 10)
# - 0431_SYS.CSV (File 3 out of 10)
# - 0432_SYS.CSV (File 4 out of 10)
# - 0433_SYS.CSV (File 5 out of 10)
# - 0434_SYS.CSV (File 6 out of 10)
# - 0435_SYS.CSV (File 7 out of 10)
# - 0436_SYS.CSV (File 8 out of 10)
# - 0437_SYS.CSV (File 9 out of 10)
# - 0438_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0429_LOC.CSV (File 1 out of 10)
# - 0430_LOC.CSV (File 2 out of 10)
# - 0431_LOC.CSV (File 3 out of 10)
# - 0432_LOC.CSV (File 4 out of 10)
# - 0433_LOC.CSV (File 5 out of 10)
# - 0434_LOC.CSV (File 6 out of 10)
# - 0435_LOC.CSV (File 7 out of 10)
# - 0436_LOC.CSV (File 8 out of 10)
# - 0437_LOC.CSV (File 9 out of 10)
# - 0438_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0429_SST.CSV (File 1 out of 10)
# - 0430_SST.CSV (File 2 out of 10)
# - 0431_SST.CSV (File 3 out of 10)
# - 0432_SST.CSV (File 4 out of 10)
# - 0433_SST.CSV (File 5 out of 10)
# - 0434_SST.CSV (File 6 out of 10)
# - 0435_SST.CSV (File 7 out of 10)
# - 0436_SST.CSV (File 8 out of 10)
# - 0437_SST.CSV (File 9 out of 10)
# - 0438_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 160 to 170 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0439_FLT.CSV (File 1 out of 10)
# - 0440_FLT.CSV (File 2 out of 10)
# - 0441_FLT.CSV (File 3 out of 10)
# - 0442_FLT.CSV (File 4 out of 10)
# - 0443_FLT.CSV (File 5 out of 10)
# - 0444_FLT.CSV (File 6 out of 10)
# - 0445_FLT.CSV (File 7 out of 10)
# - 0446_FLT.CSV (File 8 out of 10)
# - 0447_FLT.CSV (File 9 out of 10)
# - 0448_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0439_SPC.CSV (File 1 out of 10)
# - 0440_SPC.CSV (File 2 out of 10)
# - 0441_SPC.CSV (File 3 out of 10)
# - 0442_SPC.CSV (File 4 out of 10)
# - 0443_SPC.CSV (File 5 out of 10)
# - 0444_SPC.CSV (File 6 out of 10)
# - 0445_SPC.CSV (File 7 out of 10)
# - 0446_SPC.CSV (File 8 out of 10)
# - 0447_SPC.CSV (File 9 out of 10)
# - 0448_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0439_SYS.CSV (File 1 out of 10)
# - 0440_SYS.CSV (File 2 out of 10)
# - 0441_SYS.CSV (File 3 out of 10)
# - 0442_SYS.CSV (File 4 out of 10)
# - 0443_SYS.CSV (File 5 out of 10)
# - 0444_SYS.CSV (File 6 out of 10)
# - 0445_SYS.CSV (File 7 out of 10)
# - 0446_SYS.CSV (File 8 out of 10)
# - 0447_SYS.CSV (File 9 out of 10)
# - 0448_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0439_LOC.CSV (File 1 out of 10)
# - 0440_LOC.CSV (File 2 out of 10)
# - 0441_LOC.CSV (File 3 out of 10)
# - 0442_LOC.CSV (File 4 out of 10)
# - 0443_LOC.CSV (File 5 out of 10)
# - 0444_LOC.CSV (File 6 out of 10)
# - 0445_LOC.CSV (File 7 out of 10)
# - 0446_LOC.CSV (File 8 out of 10)
# - 0447_LOC.CSV (File 9 out of 10)
# - 0448_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0439_SST.CSV (File 1 out of 10)
# - 0440_SST.CSV (File 2 out of 10)
# - 0441_SST.CSV (File 3 out of 10)
# - 0442_SST.CSV (File 4 out of 10)
# - 0443_SST.CSV (File 5 out of 10)
# - 0444_SST.CSV (File 6 out of 10)
# - 0445_SST.CSV (File 7 out of 10)
# - 0446_SST.CSV (File 8 out of 10)
# - 0447_SST.CSV (File 9 out of 10)
# - 0448_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 170 to 180 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0449_FLT.CSV (File 1 out of 10)
# - 0450_FLT.CSV (File 2 out of 10)
# - 0451_FLT.CSV (File 3 out of 10)
# - 0452_FLT.CSV (File 4 out of 10)
# - 0453_FLT.CSV (File 5 out of 10)
# - 0454_FLT.CSV (File 6 out of 10)
# - 0455_FLT.CSV (File 7 out of 10)
# - 0456_FLT.CSV (File 8 out of 10)
# - 0457_FLT.CSV (File 9 out of 10)
# - 0458_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0449_SPC.CSV (File 1 out of 10)
# - 0450_SPC.CSV (File 2 out of 10)
# - 0451_SPC.CSV (File 3 out of 10)
# - 0452_SPC.CSV (File 4 out of 10)
# - 0453_SPC.CSV (File 5 out of 10)
# - 0454_SPC.CSV (File 6 out of 10)
# - 0455_SPC.CSV (File 7 out of 10)
# - 0456_SPC.CSV (File 8 out of 10)
# - 0457_SPC.CSV (File 9 out of 10)
# - 0458_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0449_SYS.CSV (File 1 out of 10)
# - 0450_SYS.CSV (File 2 out of 10)
# - 0451_SYS.CSV (File 3 out of 10)
# - 0452_SYS.CSV (File 4 out of 10)
# - 0453_SYS.CSV (File 5 out of 10)
# - 0454_SYS.CSV (File 6 out of 10)
# - 0455_SYS.CSV (File 7 out of 10)
# - 0456_SYS.CSV (File 8 out of 10)
# - 0457_SYS.CSV (File 9 out of 10)
# - 0458_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0449_LOC.CSV (File 1 out of 10)
# - 0450_LOC.CSV (File 2 out of 10)
# - 0451_LOC.CSV (File 3 out of 10)
# - 0452_LOC.CSV (File 4 out of 10)
# - 0453_LOC.CSV (File 5 out of 10)
# - 0454_LOC.CSV (File 6 out of 10)
# - 0455_LOC.CSV (File 7 out of 10)
# - 0456_LOC.CSV (File 8 out of 10)
# - 0457_LOC.CSV (File 9 out of 10)
# - 0458_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0449_SST.CSV (File 1 out of 10)
# - 0450_SST.CSV (File 2 out of 10)
# - 0451_SST.CSV (File 3 out of 10)
# - 0452_SST.CSV (File 4 out of 10)
# - 0453_SST.CSV (File 5 out of 10)
# - 0454_SST.CSV (File 6 out of 10)
# - 0455_SST.CSV (File 7 out of 10)
# - 0456_SST.CSV (File 8 out of 10)
# - 0457_SST.CSV (File 9 out of 10)
# - 0458_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 180 to 190 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0459_FLT.CSV (File 1 out of 10)
# - 0460_FLT.CSV (File 2 out of 10)
# - 0461_FLT.CSV (File 3 out of 10)
# - 0462_FLT.CSV (File 4 out of 10)
# - 0463_FLT.CSV (File 5 out of 10)
# - 0464_FLT.CSV (File 6 out of 10)
# - 0465_FLT.CSV (File 7 out of 10)
# - 0466_FLT.CSV (File 8 out of 10)
# - 0467_FLT.CSV (File 9 out of 10)
# - 0468_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0459_SPC.CSV (File 1 out of 10)
# - 0460_SPC.CSV (File 2 out of 10)
# - 0461_SPC.CSV (File 3 out of 10)
# - 0462_SPC.CSV (File 4 out of 10)
# - 0463_SPC.CSV (File 5 out of 10)
# - 0464_SPC.CSV (File 6 out of 10)
# - 0465_SPC.CSV (File 7 out of 10)
# - 0466_SPC.CSV (File 8 out of 10)
# - 0467_SPC.CSV (File 9 out of 10)
# - 0468_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0459_SYS.CSV (File 1 out of 10)
# - 0460_SYS.CSV (File 2 out of 10)
# - 0461_SYS.CSV (File 3 out of 10)
# - 0462_SYS.CSV (File 4 out of 10)
# - 0463_SYS.CSV (File 5 out of 10)
# - 0464_SYS.CSV (File 6 out of 10)
# - 0465_SYS.CSV (File 7 out of 10)
# - 0466_SYS.CSV (File 8 out of 10)
# - 0467_SYS.CSV (File 9 out of 10)
# - 0468_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0459_LOC.CSV (File 1 out of 10)
# - 0460_LOC.CSV (File 2 out of 10)
# - 0461_LOC.CSV (File 3 out of 10)
# - 0462_LOC.CSV (File 4 out of 10)
# - 0463_LOC.CSV (File 5 out of 10)
# - 0464_LOC.CSV (File 6 out of 10)
# - 0465_LOC.CSV (File 7 out of 10)
# - 0466_LOC.CSV (File 8 out of 10)
# - 0467_LOC.CSV (File 9 out of 10)
# - 0468_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0459_SST.CSV (File 1 out of 10)
# - 0460_SST.CSV (File 2 out of 10)
# - 0461_SST.CSV (File 3 out of 10)
# - 0462_SST.CSV (File 4 out of 10)
# - 0463_SST.CSV (File 5 out of 10)
# - 0464_SST.CSV (File 6 out of 10)
# - 0465_SST.CSV (File 7 out of 10)
# - 0466_SST.CSV (File 8 out of 10)
# - 0467_SST.CSV (File 9 out of 10)
# - 0468_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 190 to 200 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0469_FLT.CSV (File 1 out of 10)
# - 0470_FLT.CSV (File 2 out of 10)
# - 0471_FLT.CSV (File 3 out of 10)
# - 0472_FLT.CSV (File 4 out of 10)
# - 0473_FLT.CSV (File 5 out of 10)
# - 0474_FLT.CSV (File 6 out of 10)
# - 0475_FLT.CSV (File 7 out of 10)
# - 0476_FLT.CSV (File 8 out of 10)
# - 0477_FLT.CSV (File 9 out of 10)
# - 0478_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0469_SPC.CSV (File 1 out of 10)
# - 0470_SPC.CSV (File 2 out of 10)
# - 0471_SPC.CSV (File 3 out of 10)
# - 0472_SPC.CSV (File 4 out of 10)
# - 0473_SPC.CSV (File 5 out of 10)
# - 0474_SPC.CSV (File 6 out of 10)
# - 0475_SPC.CSV (File 7 out of 10)
# - 0476_SPC.CSV (File 8 out of 10)
# - 0477_SPC.CSV (File 9 out of 10)
# - 0478_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0469_SYS.CSV (File 1 out of 10)
# - 0470_SYS.CSV (File 2 out of 10)
# - 0471_SYS.CSV (File 3 out of 10)
# - 0472_SYS.CSV (File 4 out of 10)
# - 0473_SYS.CSV (File 5 out of 10)
# - 0474_SYS.CSV (File 6 out of 10)
# - 0475_SYS.CSV (File 7 out of 10)
# - 0476_SYS.CSV (File 8 out of 10)
# - 0477_SYS.CSV (File 9 out of 10)
# - 0478_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0469_LOC.CSV (File 1 out of 10)
# - 0470_LOC.CSV (File 2 out of 10)
# - 0471_LOC.CSV (File 3 out of 10)
# - 0472_LOC.CSV (File 4 out of 10)
# - 0473_LOC.CSV (File 5 out of 10)
# - 0474_LOC.CSV (File 6 out of 10)
# - 0475_LOC.CSV (File 7 out of 10)
# - 0476_LOC.CSV (File 8 out of 10)
# - 0477_LOC.CSV (File 9 out of 10)
# - 0478_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0469_SST.CSV (File 1 out of 10)
# - 0470_SST.CSV (File 2 out of 10)
# - 0471_SST.CSV (File 3 out of 10)
# - 0472_SST.CSV (File 4 out of 10)
# - 0473_SST.CSV (File 5 out of 10)
# - 0474_SST.CSV (File 6 out of 10)
# - 0475_SST.CSV (File 7 out of 10)
# - 0476_SST.CSV (File 8 out of 10)
# - 0477_SST.CSV (File 9 out of 10)
# - 0478_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 200 to 210 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0479_FLT.CSV (File 1 out of 10)
# - 0480_FLT.CSV (File 2 out of 10)
# - 0481_FLT.CSV (File 3 out of 10)
# - 0482_FLT.CSV (File 4 out of 10)
# - 0483_FLT.CSV (File 5 out of 10)
# - 0484_FLT.CSV (File 6 out of 10)
# - 0485_FLT.CSV (File 7 out of 10)
# - 0486_FLT.CSV (File 8 out of 10)
# - 0487_FLT.CSV (File 9 out of 10)
# - 0488_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0479_SPC.CSV (File 1 out of 10)
# - 0480_SPC.CSV (File 2 out of 10)
# - 0481_SPC.CSV (File 3 out of 10)
# - 0482_SPC.CSV (File 4 out of 10)
# - 0483_SPC.CSV (File 5 out of 10)
# - 0484_SPC.CSV (File 6 out of 10)
# - 0485_SPC.CSV (File 7 out of 10)
# - 0486_SPC.CSV (File 8 out of 10)
# - 0487_SPC.CSV (File 9 out of 10)
# - 0488_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0479_SYS.CSV (File 1 out of 10)
# - 0480_SYS.CSV (File 2 out of 10)
# - 0481_SYS.CSV (File 3 out of 10)
# - 0482_SYS.CSV (File 4 out of 10)
# - 0483_SYS.CSV (File 5 out of 10)
# - 0484_SYS.CSV (File 6 out of 10)
# - 0485_SYS.CSV (File 7 out of 10)
# - 0486_SYS.CSV (File 8 out of 10)
# - 0487_SYS.CSV (File 9 out of 10)
# - 0488_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0479_LOC.CSV (File 1 out of 10)
# - 0480_LOC.CSV (File 2 out of 10)
# - 0481_LOC.CSV (File 3 out of 10)
# - 0482_LOC.CSV (File 4 out of 10)
# - 0483_LOC.CSV (File 5 out of 10)
# - 0484_LOC.CSV (File 6 out of 10)
# - 0485_LOC.CSV (File 7 out of 10)
# - 0486_LOC.CSV (File 8 out of 10)
# - 0487_LOC.CSV (File 9 out of 10)
# - 0488_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0479_SST.CSV (File 1 out of 10)
# - 0480_SST.CSV (File 2 out of 10)
# - 0481_SST.CSV (File 3 out of 10)
# - 0482_SST.CSV (File 4 out of 10)
# - 0483_SST.CSV (File 5 out of 10)
# - 0484_SST.CSV (File 6 out of 10)
# - 0485_SST.CSV (File 7 out of 10)
# - 0486_SST.CSV (File 8 out of 10)
# - 0487_SST.CSV (File 9 out of 10)
# - 0488_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 210 to 220 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0489_FLT.CSV (File 1 out of 10)
# - 0490_FLT.CSV (File 2 out of 10)
# - 0491_FLT.CSV (File 3 out of 10)
# - 0492_FLT.CSV (File 4 out of 10)
# - 0493_FLT.CSV (File 5 out of 10)
# - 0494_FLT.CSV (File 6 out of 10)
# - 0495_FLT.CSV (File 7 out of 10)
# - 0496_FLT.CSV (File 8 out of 10)
# - 0497_FLT.CSV (File 9 out of 10)
# - 0498_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0489_SPC.CSV (File 1 out of 10)
# - 0490_SPC.CSV (File 2 out of 10)
# - 0491_SPC.CSV (File 3 out of 10)
# - 0492_SPC.CSV (File 4 out of 10)
# - 0493_SPC.CSV (File 5 out of 10)
# - 0494_SPC.CSV (File 6 out of 10)
# - 0495_SPC.CSV (File 7 out of 10)
# - 0496_SPC.CSV (File 8 out of 10)
# - 0497_SPC.CSV (File 9 out of 10)
# - 0498_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0489_SYS.CSV (File 1 out of 10)
# - 0490_SYS.CSV (File 2 out of 10)
# - 0491_SYS.CSV (File 3 out of 10)
# - 0492_SYS.CSV (File 4 out of 10)
# - 0493_SYS.CSV (File 5 out of 10)
# - 0494_SYS.CSV (File 6 out of 10)
# - 0495_SYS.CSV (File 7 out of 10)
# - 0496_SYS.CSV (File 8 out of 10)
# - 0497_SYS.CSV (File 9 out of 10)
# - 0498_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0489_LOC.CSV (File 1 out of 10)
# - 0490_LOC.CSV (File 2 out of 10)
# - 0491_LOC.CSV (File 3 out of 10)
# - 0492_LOC.CSV (File 4 out of 10)
# - 0493_LOC.CSV (File 5 out of 10)
# - 0494_LOC.CSV (File 6 out of 10)
# - 0495_LOC.CSV (File 7 out of 10)
# - 0496_LOC.CSV (File 8 out of 10)
# - 0497_LOC.CSV (File 9 out of 10)
# - 0498_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0489_SST.CSV (File 1 out of 10)
# - 0490_SST.CSV (File 2 out of 10)
# - 0491_SST.CSV (File 3 out of 10)
# - 0492_SST.CSV (File 4 out of 10)
# - 0493_SST.CSV (File 5 out of 10)
# - 0494_SST.CSV (File 6 out of 10)
# - 0495_SST.CSV (File 7 out of 10)
# - 0496_SST.CSV (File 8 out of 10)
# - 0497_SST.CSV (File 9 out of 10)
# - 0498_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 220 to 230 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0499_FLT.CSV (File 1 out of 10)
# - 0500_FLT.CSV (File 2 out of 10)
# - 0501_FLT.CSV (File 3 out of 10)
# - 0502_FLT.CSV (File 4 out of 10)
# - 0503_FLT.CSV (File 5 out of 10)
# - 0504_FLT.CSV (File 6 out of 10)
# - 0505_FLT.CSV (File 7 out of 10)
# - 0506_FLT.CSV (File 8 out of 10)
# - 0507_FLT.CSV (File 9 out of 10)
# - 0508_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0499_SPC.CSV (File 1 out of 10)
# - 0500_SPC.CSV (File 2 out of 10)
# - 0501_SPC.CSV (File 3 out of 10)
# - 0502_SPC.CSV (File 4 out of 10)
# - 0503_SPC.CSV (File 5 out of 10)
# - 0504_SPC.CSV (File 6 out of 10)
# - 0505_SPC.CSV (File 7 out of 10)
# - 0506_SPC.CSV (File 8 out of 10)
# - 0507_SPC.CSV (File 9 out of 10)
# - 0508_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0499_SYS.CSV (File 1 out of 10)
# - 0500_SYS.CSV (File 2 out of 10)
# - 0501_SYS.CSV (File 3 out of 10)
# - 0502_SYS.CSV (File 4 out of 10)
# - 0503_SYS.CSV (File 5 out of 10)
# - 0504_SYS.CSV (File 6 out of 10)
# - 0505_SYS.CSV (File 7 out of 10)
# - 0506_SYS.CSV (File 8 out of 10)
# - 0507_SYS.CSV (File 9 out of 10)
# - 0508_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0499_LOC.CSV (File 1 out of 10)
# - 0500_LOC.CSV (File 2 out of 10)
# - 0501_LOC.CSV (File 3 out of 10)
# - 0502_LOC.CSV (File 4 out of 10)
# - 0503_LOC.CSV (File 5 out of 10)
# - 0504_LOC.CSV (File 6 out of 10)
# - 0505_LOC.CSV (File 7 out of 10)
# - 0506_LOC.CSV (File 8 out of 10)
# - 0507_LOC.CSV (File 9 out of 10)
# - 0508_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0499_SST.CSV (File 1 out of 10)
# - 0500_SST.CSV (File 2 out of 10)
# - 0501_SST.CSV (File 3 out of 10)
# - 0502_SST.CSV (File 4 out of 10)
# - 0503_SST.CSV (File 5 out of 10)
# - 0504_SST.CSV (File 6 out of 10)
# - 0505_SST.CSV (File 7 out of 10)
# - 0506_SST.CSV (File 8 out of 10)
# - 0507_SST.CSV (File 9 out of 10)
# - 0508_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 230 to 240 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0509_FLT.CSV (File 1 out of 10)
# - 0510_FLT.CSV (File 2 out of 10)
# - 0511_FLT.CSV (File 3 out of 10)
# - 0512_FLT.CSV (File 4 out of 10)
# - 0513_FLT.CSV (File 5 out of 10)
# - 0514_FLT.CSV (File 6 out of 10)
# - 0515_FLT.CSV (File 7 out of 10)
# - 0516_FLT.CSV (File 8 out of 10)
# - 0517_FLT.CSV (File 9 out of 10)
# - 0518_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0509_SPC.CSV (File 1 out of 10)
# - 0510_SPC.CSV (File 2 out of 10)
# - 0511_SPC.CSV (File 3 out of 10)
# - 0512_SPC.CSV (File 4 out of 10)
# - 0513_SPC.CSV (File 5 out of 10)
# - 0514_SPC.CSV (File 6 out of 10)
# - 0515_SPC.CSV (File 7 out of 10)
# - 0516_SPC.CSV (File 8 out of 10)
# - 0517_SPC.CSV (File 9 out of 10)
# - 0518_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0509_SYS.CSV (File 1 out of 10)
# - 0510_SYS.CSV (File 2 out of 10)
# - 0511_SYS.CSV (File 3 out of 10)
# - 0512_SYS.CSV (File 4 out of 10)
# - 0513_SYS.CSV (File 5 out of 10)
# - 0514_SYS.CSV (File 6 out of 10)
# - 0515_SYS.CSV (File 7 out of 10)
# - 0516_SYS.CSV (File 8 out of 10)
# - 0517_SYS.CSV (File 9 out of 10)
# - 0518_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0509_LOC.CSV (File 1 out of 10)
# - 0510_LOC.CSV (File 2 out of 10)
# - 0511_LOC.CSV (File 3 out of 10)
# - 0512_LOC.CSV (File 4 out of 10)
# - 0513_LOC.CSV (File 5 out of 10)
# - 0514_LOC.CSV (File 6 out of 10)
# - 0515_LOC.CSV (File 7 out of 10)
# - 0516_LOC.CSV (File 8 out of 10)
# - 0517_LOC.CSV (File 9 out of 10)
# - 0518_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0509_SST.CSV (File 1 out of 10)
# - 0510_SST.CSV (File 2 out of 10)
# - 0511_SST.CSV (File 3 out of 10)
# - 0512_SST.CSV (File 4 out of 10)
# - 0513_SST.CSV (File 5 out of 10)
# - 0514_SST.CSV (File 6 out of 10)
# - 0515_SST.CSV (File 7 out of 10)
# - 0516_SST.CSV (File 8 out of 10)
# - 0517_SST.CSV (File 9 out of 10)
# - 0518_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 240 to 250 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0519_FLT.CSV (File 1 out of 10)
# - 0520_FLT.CSV (File 2 out of 10)
# - 0521_FLT.CSV (File 3 out of 10)
# - 0522_FLT.CSV (File 4 out of 10)
# - 0523_FLT.CSV (File 5 out of 10)
# - 0524_FLT.CSV (File 6 out of 10)
# - 0525_FLT.CSV (File 7 out of 10)
# - 0526_FLT.CSV (File 8 out of 10)
# - 0527_FLT.CSV (File 9 out of 10)
# - 0528_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0519_SPC.CSV (File 1 out of 10)
# - 0520_SPC.CSV (File 2 out of 10)
# - 0521_SPC.CSV (File 3 out of 10)
# - 0522_SPC.CSV (File 4 out of 10)
# - 0523_SPC.CSV (File 5 out of 10)
# - 0524_SPC.CSV (File 6 out of 10)
# - 0525_SPC.CSV (File 7 out of 10)
# - 0526_SPC.CSV (File 8 out of 10)
# - 0527_SPC.CSV (File 9 out of 10)
# - 0528_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0519_SYS.CSV (File 1 out of 10)
# - 0520_SYS.CSV (File 2 out of 10)
# - 0521_SYS.CSV (File 3 out of 10)
# - 0522_SYS.CSV (File 4 out of 10)
# - 0523_SYS.CSV (File 5 out of 10)
# - 0524_SYS.CSV (File 6 out of 10)
# - 0525_SYS.CSV (File 7 out of 10)
# - 0526_SYS.CSV (File 8 out of 10)
# - 0527_SYS.CSV (File 9 out of 10)
# - 0528_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0519_LOC.CSV (File 1 out of 10)
# - 0520_LOC.CSV (File 2 out of 10)
# - 0521_LOC.CSV (File 3 out of 10)
# - 0522_LOC.CSV (File 4 out of 10)
# - 0523_LOC.CSV (File 5 out of 10)
# - 0524_LOC.CSV (File 6 out of 10)
# - 0525_LOC.CSV (File 7 out of 10)
# - 0526_LOC.CSV (File 8 out of 10)
# - 0527_LOC.CSV (File 9 out of 10)
# - 0528_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0519_SST.CSV (File 1 out of 10)
# - 0520_SST.CSV (File 2 out of 10)
# - 0521_SST.CSV (File 3 out of 10)
# - 0522_SST.CSV (File 4 out of 10)
# - 0523_SST.CSV (File 5 out of 10)
# - 0524_SST.CSV (File 6 out of 10)
# - 0525_SST.CSV (File 7 out of 10)
# - 0526_SST.CSV (File 8 out of 10)
# - 0527_SST.CSV (File 9 out of 10)
# - 0528_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Processing files 250 to 260 out of 260
# WARNING: Cannot determine version number
# Concatenating all FLT files:
# - 0529_FLT.CSV (File 1 out of 10)
# - 0530_FLT.CSV (File 2 out of 10)
# - 0531_FLT.CSV (File 3 out of 10)
# - 0532_FLT.CSV (File 4 out of 10)
# - 0533_FLT.CSV (File 5 out of 10)
# - 0534_FLT.CSV (File 6 out of 10)
# - 0535_FLT.CSV (File 7 out of 10)
# - 0536_FLT.CSV (File 8 out of 10)
# - 0537_FLT.CSV (File 9 out of 10)
# - 0538_FLT.CSV (File 10 out of 10)
# Processing spotter displacement output
# - IIR phase correction using weight type:  0
# Concatenating all SPC files:
# - 0529_SPC.CSV (File 1 out of 10)
# - 0530_SPC.CSV (File 2 out of 10)
# - 0531_SPC.CSV (File 3 out of 10)
# - 0532_SPC.CSV (File 4 out of 10)
# - 0533_SPC.CSV (File 5 out of 10)
# - 0534_SPC.CSV (File 6 out of 10)
# - 0535_SPC.CSV (File 7 out of 10)
# - 0536_SPC.CSV (File 8 out of 10)
# - 0537_SPC.CSV (File 9 out of 10)
# - 0538_SPC.CSV (File 10 out of 10)
# Processing spotter spectral output
# Concatenating all SYS files:
# - 0529_SYS.CSV (File 1 out of 10)
# - 0530_SYS.CSV (File 2 out of 10)
# - 0531_SYS.CSV (File 3 out of 10)
# - 0532_SYS.CSV (File 4 out of 10)
# - 0533_SYS.CSV (File 5 out of 10)
# - 0534_SYS.CSV (File 6 out of 10)
# - 0535_SYS.CSV (File 7 out of 10)
# - 0536_SYS.CSV (File 8 out of 10)
# - 0537_SYS.CSV (File 9 out of 10)
# - 0538_SYS.CSV (File 10 out of 10)
# Concatenating all LOC files:
# - 0529_LOC.CSV (File 1 out of 10)
# - 0530_LOC.CSV (File 2 out of 10)
# - 0531_LOC.CSV (File 3 out of 10)
# - 0532_LOC.CSV (File 4 out of 10)
# - 0533_LOC.CSV (File 5 out of 10)
# - 0534_LOC.CSV (File 6 out of 10)
# - 0535_LOC.CSV (File 7 out of 10)
# - 0536_LOC.CSV (File 8 out of 10)
# - 0537_LOC.CSV (File 9 out of 10)
# - 0538_LOC.CSV (File 10 out of 10)
# Processing spotter displacement output
# Concatenating all GPS files:
#   No _GPS data files available.
# Concatenating all SST files:
# - 0529_SST.CSV (File 1 out of 10)
# - 0530_SST.CSV (File 2 out of 10)
# - 0531_SST.CSV (File 3 out of 10)
# - 0532_SST.CSV (File 4 out of 10)
# - 0533_SST.CSV (File 5 out of 10)
# - 0534_SST.CSV (File 6 out of 10)
# - 0535_SST.CSV (File 7 out of 10)
# - 0536_SST.CSV (File 8 out of 10)
# - 0537_SST.CSV (File 9 out of 10)
# - 0538_SST.CSV (File 10 out of 10)
# Processing spotter displacement output
# Finished processing SPOT-0561

# %%
#%% clean up for export
os.chdir(outpath)
shutil.rmtree(tmp_path)
############# BULKPARAMS ###############################################
bulkparams = bulkparams.rename(columns={bulkparams.columns[0]:'time'})
bulkparams = bulkparams.set_index('time').tz_localize(tz='UTC')
bulkparams.to_csv(os.path.join(outpath,buoyID+'_bulkparams.csv'))

########### DISPLACEMENTS ################################################
displacements = displacements.rename(columns={displacements.columns[0]:'time'})
displacements = displacements.set_index('time').tz_localize(tz='UTC')
displacements.to_csv(os.path.join(outpath,buoyID+'_displacements.csv'))

########### LOCATIONS ######################################################
locations = locations.rename(columns={locations.columns[0]:'time'})
locations = locations.set_index('time').tz_localize(tz='UTC')
locations.to_csv(os.path.join(outpath,buoyID+'_locations.csv'))

############ A1 ###########################################################
a1 = a1.rename(columns={a1.columns[0]:'time'})
a1 = a1.set_index('time').tz_localize(tz='UTC')
a1.to_csv(os.path.join(outpath,buoyID+'_a1.csv'))

############ A2 ###########################################################
a2 = a2.rename(columns={a2.columns[0]:'time'})
a2 = a2.set_index('time').tz_localize(tz='UTC')
a2.to_csv(os.path.join(outpath,buoyID+'_a2.csv'))

############ b1 ###########################################################
b1 = b1.rename(columns={b1.columns[0]:'time'})
b1 = b1.set_index('time').tz_localize(tz='UTC')
b1.to_csv(os.path.join(outpath,buoyID+'_b1.csv'))

############ b2 ###########################################################
b2 = b2.rename(columns={b2.columns[0]:'time'})
b2 = b2.set_index('time').tz_localize(tz='UTC')
b2.to_csv(os.path.join(outpath,buoyID+'_b2.csv'))

############ Sxx ###########################################################
Sxx = Sxx.rename(columns={Sxx.columns[0]:'time'})
Sxx = Sxx.set_index('time').tz_localize(tz='UTC')
Sxx.to_csv(os.path.join(outpath,buoyID+'_Sxx.csv'))

############ Syy ###########################################################
Syy = Syy.rename(columns={Syy.columns[0]:'time'})
Syy = Syy.set_index('time').tz_localize(tz='UTC')
Syy.to_csv(os.path.join(outpath,buoyID+'_Syy.csv'))

############ Szz ###########################################################
Szz = Szz.rename(columns={Szz.columns[0]:'time'})
Szz = Szz.set_index('time').tz_localize(tz='UTC')
Szz.to_csv(os.path.join(outpath,buoyID+'_Szz.csv'))

############ SST ###########################################################
sst = sst.rename(columns={sst.columns[0]:'time'})
sst = sst.set_index('time').tz_localize(tz='UTC')
sst.to_csv(os.path.join(outpath,buoyID+'_sst.csv'))
print('done exporting processed data')
